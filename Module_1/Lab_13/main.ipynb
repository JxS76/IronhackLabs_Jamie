# %%
import requests
import json

response = requests.get('https://jsonplaceholder.typicode.com/todos')
response.status_code
results = response.json()

import pandas as pd
data = pd.DataFrame(results)
data.head(10)
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False
# 5       1   6  qui ullam ratione quibusdam voluptatem quia omnis      False
# 6       1   7                  illo expedita consequatur quia in      False
# 7       1   8                       quo adipisci enim quam ut ab       True
# 8       1   9                        molestiae perspiciatis ipsa      False
# 9       1  10       illo est ratione doloremque quia maiores aut       True

# %%
response = requests.get('https://api.github.com/events')
data = pd.DataFrame(response.json())

data.head(10)
# Out:
#             id               type  \
# 0  20494734542  IssueCommentEvent
# 1  20494734521          PushEvent
# 2  20494734564         WatchEvent
# 3  20494734510         WatchEvent
# 4  20494734528          PushEvent
# 5  20494734525          PushEvent
# 6  20494734536          PushEvent
# 7  20494734534          PushEvent
# 8  20494734512          PushEvent
# 9  20494734522          PushEvent
#
#                                                actor  \
# 0  {'id': 20407524, 'login': 'k8s-ci-robot', 'dis...
# 1  {'id': 69317922, 'login': 'piyush-mishra-pm', ...
# 2  {'id': 18283033, 'login': 'jopemachine', 'disp...
# 3  {'id': 1615568, 'login': 'andychisholm', 'disp...
# 4  {'id': 25152892, 'login': 'mimidotsuser', 'dis...
# 5  {'id': 36600763, 'login': 'ParisaMollahoseini'...
# 6  {'id': 63877, 'login': 'hooopo', 'display_logi...
# 7  {'id': 10810283, 'login': 'direwolf-github', '...
# 8  {'id': 19253721, 'login': 'pmamico', 'display_...
# 9  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                 repo  \
# 0  {'id': 20580498, 'name': 'kubernetes/kubernete...
# 1  {'id': 463621190, 'name': 'piyush-mishra-pm/Qu...
# 2  {'id': 81045648, 'name': 'ISKU/BOJ-AutoCommit'...
# 3  {'id': 203587744, 'name': 'hoppscotch/hoppscot...
# 4  {'id': 461267940, 'name': 'mimidotsuser/ppaw',...
# 5  {'id': 456528646, 'name': 'ParisaMollahoseini/...
# 6  {'id': 449649595, 'name': 'pingcap-inc/gharchi...
# 7  {'id': 464441803, 'name': 'direwolf-github/eph...
# 8  {'id': 464441742, 'name': 'pmamico/contributio...
# 9  {'id': 353600147, 'name': 'brocjad/pub_hofs', ...
#
#                                              payload  public  \
# 0  {'action': 'created', 'issue': {'url': 'https:...    True
# 1  {'push_id': 9221924499, 'size': 1, 'distinct_s...    True
# 2                              {'action': 'started'}    True
# 3                              {'action': 'started'}    True
# 4  {'push_id': 9221924491, 'size': 3, 'distinct_s...    True
# 5  {'push_id': 9221924477, 'size': 1, 'distinct_s...    True
# 6  {'push_id': 9221924464, 'size': 1, 'distinct_s...    True
# 7  {'push_id': 9221924478, 'size': 1, 'distinct_s...    True
# 8  {'push_id': 9221924469, 'size': 106, 'distinct...    True
# 9  {'push_id': 9221924489, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org
# 0  2022-02-28T10:45:13Z  {'id': 13629408, 'login': 'kubernetes', 'grava...
# 1  2022-02-28T10:45:13Z                                                NaN
# 2  2022-02-28T10:45:13Z                                                NaN
# 3  2022-02-28T10:45:13Z  {'id': 56705483, 'login': 'hoppscotch', 'grava...
# 4  2022-02-28T10:45:13Z                                                NaN
# 5  2022-02-28T10:45:13Z                                                NaN
# 6  2022-02-28T10:45:13Z  {'id': 88425602, 'login': 'pingcap-inc', 'grav...
# 7  2022-02-28T10:45:13Z                                                NaN
# 8  2022-02-28T10:45:13Z                                                NaN
# 9  2022-02-28T10:45:13Z                                                NaN

# %%
response = requests.get('https://api.github.com/events')
flattened_data = pd.json_normalize(results)
flattened_data
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data,flattened],axis=1)
    return data
nested_columns = ['actor', 'org', 'payload', 'repo']
flat = flatten(data, nested_columns)
flat.head(10)
# Out:
#             id               type  \
# 0  20494734542  IssueCommentEvent
# 1  20494734521          PushEvent
# 2  20494734564         WatchEvent
# 3  20494734510         WatchEvent
# 4  20494734528          PushEvent
# 5  20494734525          PushEvent
# 6  20494734536          PushEvent
# 7  20494734534          PushEvent
# 8  20494734512          PushEvent
# 9  20494734522          PushEvent
#
#                                                actor  \
# 0  {'id': 20407524, 'login': 'k8s-ci-robot', 'dis...
# 1  {'id': 69317922, 'login': 'piyush-mishra-pm', ...
# 2  {'id': 18283033, 'login': 'jopemachine', 'disp...
# 3  {'id': 1615568, 'login': 'andychisholm', 'disp...
# 4  {'id': 25152892, 'login': 'mimidotsuser', 'dis...
# 5  {'id': 36600763, 'login': 'ParisaMollahoseini'...
# 6  {'id': 63877, 'login': 'hooopo', 'display_logi...
# 7  {'id': 10810283, 'login': 'direwolf-github', '...
# 8  {'id': 19253721, 'login': 'pmamico', 'display_...
# 9  {'id': 41898282, 'login': 'github-actions[bot]...
#
#                                                 repo  \
# 0  {'id': 20580498, 'name': 'kubernetes/kubernete...
# 1  {'id': 463621190, 'name': 'piyush-mishra-pm/Qu...
# 2  {'id': 81045648, 'name': 'ISKU/BOJ-AutoCommit'...
# 3  {'id': 203587744, 'name': 'hoppscotch/hoppscot...
# 4  {'id': 461267940, 'name': 'mimidotsuser/ppaw',...
# 5  {'id': 456528646, 'name': 'ParisaMollahoseini/...
# 6  {'id': 449649595, 'name': 'pingcap-inc/gharchi...
# 7  {'id': 464441803, 'name': 'direwolf-github/eph...
# 8  {'id': 464441742, 'name': 'pmamico/contributio...
# 9  {'id': 353600147, 'name': 'brocjad/pub_hofs', ...
#
#                                              payload  public  \
# 0  {'action': 'created', 'issue': {'url': 'https:...    True
# 1  {'push_id': 9221924499, 'size': 1, 'distinct_s...    True
# 2                              {'action': 'started'}    True
# 3                              {'action': 'started'}    True
# 4  {'push_id': 9221924491, 'size': 3, 'distinct_s...    True
# 5  {'push_id': 9221924477, 'size': 1, 'distinct_s...    True
# 6  {'push_id': 9221924464, 'size': 1, 'distinct_s...    True
# 7  {'push_id': 9221924478, 'size': 1, 'distinct_s...    True
# 8  {'push_id': 9221924469, 'size': 106, 'distinct...    True
# 9  {'push_id': 9221924489, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org  \
# 0  2022-02-28T10:45:13Z  {'id': 13629408, 'login': 'kubernetes', 'grava...
# 1  2022-02-28T10:45:13Z                                                NaN
# 2  2022-02-28T10:45:13Z                                                NaN
# 3  2022-02-28T10:45:13Z  {'id': 56705483, 'login': 'hoppscotch', 'grava...
# 4  2022-02-28T10:45:13Z                                                NaN
# 5  2022-02-28T10:45:13Z                                                NaN
# 6  2022-02-28T10:45:13Z  {'id': 88425602, 'login': 'pingcap-inc', 'grav...
# 7  2022-02-28T10:45:13Z                                                NaN
# 8  2022-02-28T10:45:13Z                                                NaN
# 9  2022-02-28T10:45:13Z                                                NaN
#
#    actor_id          actor_login  ... payload_ref_type payload_master_branch  \
# 0  20407524         k8s-ci-robot  ...              NaN                   NaN
# 1  69317922     piyush-mishra-pm  ...              NaN                   NaN
# 2  18283033          jopemachine  ...              NaN                   NaN
# 3   1615568         andychisholm  ...              NaN                   NaN
# 4  25152892         mimidotsuser  ...              NaN                   NaN
# 5  36600763   ParisaMollahoseini  ...              NaN                   NaN
# 6     63877               hooopo  ...              NaN                   NaN
# 7  10810283      direwolf-github  ...              NaN                   NaN
# 8  19253721              pmamico  ...              NaN                   NaN
# 9  41898282  github-actions[bot]  ...              NaN                   NaN
#
#   payload_description payload_pusher_type payload_member payload_review  \
# 0                 NaN                 NaN            NaN            NaN
# 1                 NaN                 NaN            NaN            NaN
# 2                 NaN                 NaN            NaN            NaN
# 3                 NaN                 NaN            NaN            NaN
# 4                 NaN                 NaN            NaN            NaN
# 5                 NaN                 NaN            NaN            NaN
# 6                 NaN                 NaN            NaN            NaN
# 7                 NaN                 NaN            NaN            NaN
# 8                 NaN                 NaN            NaN            NaN
# 9                 NaN                 NaN            NaN            NaN
#
#   payload_pull_request    repo_id  \
# 0                  NaN   20580498
# 1                  NaN  463621190
# 2                  NaN   81045648
# 3                  NaN  203587744
# 4                  NaN  461267940
# 5                  NaN  456528646
# 6                  NaN  449649595
# 7                  NaN  464441803
# 8                  NaN  464441742
# 9                  NaN  353600147
#
#                                            repo_name  \
# 0                              kubernetes/kubernetes
# 1                           piyush-mishra-pm/QuoteIt
# 2                                ISKU/BOJ-AutoCommit
# 3                              hoppscotch/hoppscotch
# 4                                  mimidotsuser/ppaw
# 5  ParisaMollahoseini/Action_recognition_with_kin...
# 6                         pingcap-inc/gharchive.live
# 7              direwolf-github/ephemeral-ci-8051e776
# 8                  pmamico/contribution-clock-engine
# 9                                   brocjad/pub_hofs
#
#                                             repo_url
# 0  https://api.github.com/repos/kubernetes/kubern...
# 1  https://api.github.com/repos/piyush-mishra-pm/...
# 2   https://api.github.com/repos/ISKU/BOJ-AutoCommit
# 3  https://api.github.com/repos/hoppscotch/hoppsc...
# 4     https://api.github.com/repos/mimidotsuser/ppaw
# 5  https://api.github.com/repos/ParisaMollahosein...
# 6  https://api.github.com/repos/pingcap-inc/gharc...
# 7  https://api.github.com/repos/direwolf-github/e...
# 8  https://api.github.com/repos/pmamico/contribut...
# 9      https://api.github.com/repos/brocjad/pub_hofs
#
# [10 rows x 39 columns]

# %%
import requests

headers = {'content-type': 'multipart/form-data'}
r = requests.get('https://xkcd.com', headers=headers)

print(r.headers)
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3021', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Mon, 28 Feb 2022 05:00:04 GMT', 'ETag': 'W/"621c56d4-1ddd"', 'Expires': 'Mon, 28 Feb 2022 05:05:43 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 28 Feb 2022 11:33:38 GMT', 'Age': '124', 'X-Served-By': 'cache-dfw18627-DFW, cache-cdg20777-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '1, 1', 'X-Timer': 'S1646048018.363785,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
#'Expires': 'Mon, 28 Feb 2022 05:05:43 GMT',

# %%
#provide all HTML codes
<!DOCTYPE html>
<html>
<head>
<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>
<title>xkcd: Greek Letters</title>
<meta http-equiv="X-UA-Compatible" content="IE=edge"/>
<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>
<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>
<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>
<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>
<script type="text/javascript" src="/s/b66ed7.js" async></script>
<script type="text/javascript" src="/s/1b9456.js" async></script>

<meta property="og:site_name" content="xkcd">

<meta property="og:title" content="Greek Letters">
<meta property="og:url" content="https://xkcd.com/2586/">
<meta property="og:image" content="https://imgs.xkcd.com/comics/greek_letters_2x.png">
<meta name="twitter:card" content="summary_large_image">

</head>
<body>
<div id="topContainer">
<div id="topLeft">
<ul>
<li><a href="/archive">Archive</a></li>
<li><a href="https://what-if.xkcd.com">What If?</a></li>
<li><a href="https://blag.xkcd.com">Blag</a></li>
<li><a rel="author" href="/about">About</a></li>
<li><a href="/atom.xml">Feed</a>&bull;<a href="/newsletter/">Email</a></li>
<li><a href="https://twitter.com/xkcd/">TW</a>&bull;<a href="https://www.facebook.com/TheXKCD/">FB</a>&bull;<a href="https://www.instagram.com/xkcd/">IG</a></li>
<li><a href="/books/">-Books-</a></li>
<li><a href="/what-if-2/">What If? 2</a></li>
<li><a href="/what-if/">WI?</a>&bull;<a href="/thing-explainer/">TE</a>&bull;<a href="/how-to/">HT</a></li>
</ul>
</div>
<div id="topRight">
<div id="masthead">
<span><a href="/"><img src="/s/0b7742.png" alt="xkcd.com logo" height="83" width="185"/></a></span>
<span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>
</div>
<div id="news">
<div id="countdown" style="float: right; margin-right: 25px; width: 160px; height: 100px; position: relative;"><a style="display: flex;" href="https://xkcd.com/what-if-2/"><img alt="" style="width: 160px; height: 100px;" src="https://xkcd.com/s/5bef6b.png"><span style="position: absolute; left: 50%; top: 50%; transform: translate(-50%, -50%); padding: 0px 8px; color: black; font-family: xkcd-Regular-v3; font-size: 20px; font-variant: small-caps; letter-spacing: 1px; white-space: nowrap; background: white none repeat scroll 0% 0%; border-radius: 99px; display: none;"></span></a></div>
<em>What If? 2: Additional Serious Scientific Answers to Absurd Hypothetical Questions</em> comes out 9/13. Preorder <a href="https://xkcd.com/what-if-2">here!</a>

</div>
</div>
<div id="bgLeft" class="bg box"></div>
<div id="bgRight" class="bg box"></div>
</div>
<div id="middleContainer" class="box">

<div id="ctitle">Greek Letters</div>
<ul class="comicNav">
<li><a href="/1/">|&lt;</a></li>
<li><a rel="prev" href="/2585/" accesskey="p">&lt; Prev</a></li>
<li><a href="//c.xkcd.com/random/comic/">Random</a></li>
<li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>
<li><a href="/">&gt;|</a></li>
</ul>
<div id="comic">
<img src="//imgs.xkcd.com/comics/greek_letters.png" title="If you ever see someone using a capital xi in an equation, just observe them quietly to learn as much as you can before they return to their home planet." alt="Greek Letters" srcset="//imgs.xkcd.com/comics/greek_letters_2x.png 2x" style="image-orientation:none" />
</div>
<ul class="comicNav">
<li><a href="/1/">|&lt;</a></li>
<li><a rel="prev" href="/2585/" accesskey="p">&lt; Prev</a></li>
100  7645  100  7645    0     0  29802      0 --:--:-- --:--:-- --:--:-- 30098comic/">Random</a></li>
<li><a rel="next" href="#" accesskey="n">Next &gt;</a></li>
<li><a href="/">&gt;|</a></li>
</ul>
<br />
Permanent link to this comic: <a href="https://xkcd.com/2586">https://xkcd.com/2586/</a><br />
Image URL (for hotlinking/embedding): <a href= "https://imgs.xkcd.com/comics/greek_letters.png">https://imgs.xkcd.com/comics/greek_letters.png</a>

<div id="transcript" style="display: none"></div>
</div>
<div id="bottom" class="box">
<img src="//imgs.xkcd.com/s/a899e84.jpg" width="520" height="100" alt="Selected Comics" usemap="#comicmap"/>
<map id="comicmap" name="comicmap">
<area shape="rect" coords="0,0,100,100" href="/150/" alt="Grownups"/>
<area shape="rect" coords="104,0,204,100" href="/730/" alt="Circuit Diagram"/>
<area shape="rect" coords="208,0,308,100" href="/162/" alt="Angular Momentum"/>
<area shape="rect" coords="312,0,412,100" href="/688/" alt="Self-Description"/>
<area shape="rect" coords="416,0,520,100" href="/556/" alt="Alternative Energy Revolution"/>
</map>
<br />
<a href="//xkcd.com/1732/"><img border=0 src="//imgs.xkcd.com/s/temperature.png" width="520" height="100" alt="Earth temperature timeline"></a>
<br />
<div>
<!--
Search comic titles and transcripts:
<script type="text/javascript" src="//www.google.com/jsapi"></script>
<script type="text/javascript">google.load('search', '1');google.setOnLoadCallback(function() {google.search.CustomSearchControl.attachAutoCompletion('012652707207066138651:zudjtuwe28q',document.getElementById('q'),'cse-search-box');});</script>
<form action="//www.google.com/cse" id="cse-search-box">
<div>
<input type="hidden" name="cx" value="012652707207066138651:zudjtuwe28q"/>
<input type="hidden" name="ie" value="UTF-8"/>
<input type="text" name="q" id="q" size="31"/>
<input type="submit" name="sa" value="Search"/>
</div>
</form>
<script type="text/javascript" src="//www.google.com/cse/brand?form=cse-search-box&amp;lang=en"></script>
-->
<a href="/rss.xml">RSS Feed</a> - <a href="/atom.xml">Atom Feed</a> - <a href="/newsletter/">Email</a>
</div>
<br />
<div id="comicLinks">
Comics I enjoy:<br/>
        <a href="http://threewordphrase.com/">Three Word Phrase</a>,
        <a href="https://www.smbc-comics.com/">SMBC</a>,
        <a href="https://www.qwantz.com">Dinosaur Comics</a>,
        <a href="https://oglaf.com/">Oglaf</a> (nsfw),
        <a href="https://www.asofterworld.com">A Softer World</a>,
        <a href="https://buttersafe.com/">Buttersafe</a>,
        <a href="https://pbfcomics.com/">Perry Bible Fellowship</a>,
        <a href="https://questionablecontent.net/">Questionable Content</a>,
        <a href="http://www.buttercupfestival.com/">Buttercup Festival</a>,
        <a href="https://www.mspaintadventures.com/">Homestuck</a>,
        <a href="https://www.jspowerhour.com/">Junior Scientist Power Hour</a>
</div>
<br />
<div id="comicLinks">
Other things:<br/>
        <a href="https://medium.com/civic-tech-thoughts-from-joshdata/so-you-want-to-reform-democracy-7f3b1ef10597">Tips on technology and government</a>,<br />
        <a href="https://www.nytimes.com/interactive/2017/climate/what-is-climate-change.html">Climate FAQ</a>,
        <a href="https://twitter.com/KHayhoe">Katharine Hayhoe</a>
</div>
<br />
<center>
<div id="footnote" style="width:70%">xkcd.com is best viewed with Netscape Navigator 4.0 or below on a Pentium 3&plusmn;1 emulated in Javascript on an Apple IIGS<br />at a screen resolution of 1024x1. Please enable your ad blockers, disable high-heat drying, and remove your device<br />from Airplane Mode and set it to Boat Mode. For security reasons, please leave caps lock on while browsing.</div>
</center>
<div id="licenseText">
<p>
This work is licensed under a
<a href="https://creativecommons.org/licenses/by-nc/2.5/">Creative Commons Attribution-NonCommercial 2.5 License</a>.
</p><p>
This means you're free to copy and share these comics (but not to sell them). <a rel="license" href="/license.html">More details</a>.</p>
</div>
</div>
</body>
<!-- Layout by Ian Clasbey, davean, and chromakode -->
</html

# %%
response = requests.get('http://imgs.xkcd.com/comics/greek_letters.png')
with open (r'/Users/Jamie/Ironhack/image.png','wb') as f:
    f.write(response.content)

# %%
ploads = {'things':2,'total':25}
ploads = requests.get('https://httpbin.org/get', params=ploads)
ploads.content
# Out:
# b'{\n  "args": {\n    "things": "2", \n    "total": "25"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.26.0", \n    "X-Amzn-Trace-Id": "Root=1-621cd646-381f792254f4e3c84499fc14"\n  }, \n  "origin": "195.134.167.217", \n  "url": "https://httpbin.org/get?things=2&total=25"\n}\n'

# %%
ploads = {'username123': 'password123'}
response = requests.post('https://httpbin.org/post', data=ploads)
ploads
# Out:
# {'username123': 'password123'}

# %%
#export as dictionary
ploads = {'Username':'123','Password':'password123'}
r = requests.post('https://httpbin.org/post',data=ploads)
r_dict = r.json()
print(r_dict['form'])
# Out:
# {'Password': 'password123', 'Username': '123'}

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger')
search = response.json()
print(search)
# Out:
# {'total_count': 24, 'incomplete_results': False, 'items': [{'name': '.0016.scavengerhunt', 'path': '47222/.0016.scavengerhunt', 'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476', 'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0', 'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt', 'repository': {'id': 162375181, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=', 'name': 'scavenger', 'full_name': 'ironhack-datalabs/scavenger', 'private': False, 'owner': {'login': 'ironhack-datalabs', 'id': 44225188, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4', 'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/ironhack-datalabs', 'html_url': 'https://github.com/ironhack-datalabs', 'followers_url': 'https://api.github.com/users/ironhack-datalabs/followers', 'following_url': 'https://api.github.com/users/ironhack-datalabs/following{/other_user}', 'gists_url': 'https://api.github.com/users/ironhack-datalabs/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/ironhack-datalabs/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/ironhack-datalabs/subscriptions', 'organizations_url': 'https://api.github.com/users/ironhack-datalabs/orgs', 'repos_url': 'https://api.github.com/users/ironhack-datalabs/repos', 'events_url': 'https://api.github.com/users/ironhack-datalabs/events{/privacy}', 'received_events_url': 'https://api.github.com/users/ironhack-datalabs/received_events', 'type': 'Organization', 'site_admin': False}, 'html_url': 'https://github.com/ironhack-datalabs/scavenger', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger', 'forks_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/forks', 'keys_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/teams', 'hooks_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/hooks', 'issue_events_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/issues/events{/number}', 'events_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/events', 'assignees_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/assignees{/user}', 'branches_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/branches{/branch}', 'tags_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/tags', 'blobs_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/languages', 'stargazers_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/stargazers', 'contributors_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contributors', 'subscribers_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/subscribers', 'subscription_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/subscription', 'commits_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/ironhack-datal ...

# %%
files = search['items'];
files = sorted(files, key=lambda file: file['name']);
contents_list = []
headers = {'Accept': 'application/vnd.github.v3.raw', };

# %%
import tweepy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15688/657247260.py in <module>
# ----> 1 import tweepy
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
pip install tweepy
# Out:
# Collecting tweepy
#   Downloading tweepy-4.6.0-py2.py3-none-any.whl (69 kB)
# Collecting requests-oauthlib<2,>=1.2.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib<4,>=3.2.0
#   Downloading oauthlib-3.2.0-py3-none-any.whl (151 kB)
# Collecting requests<3,>=2.27.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jamie\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jamie\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jamie\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jamie\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.7)
# Installing collected packages: requests, oauthlib, requests-oauthlib, tweepy
#   Attempting uninstall: requests
#     Found existing installation: requests 2.26.0
#     Uninstalling requests-2.26.0:
#       Successfully uninstalled requests-2.26.0
# Successfully installed oauthlib-3.2.0 requests-2.27.1 requests-oauthlib-1.3.1 tweepy-4.6.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.4 requires pathlib, which is not installed.
# anaconda-project 0.10.1 requires ruamel-yaml, which is not installed.

# %%
def search_twitter(query, tweet_fields, bearer_token = 'AAAAAAAAAAAAAAAAAAAAAFfoZgEAAAAAR8cAl2V37CUrUQ5lDePVnjHNfAA%3DoRUnSWMlcIpWrm76oZToXJETBUrKlvmQccKFZoKniFOp8tRSjK'):
    headers = {"Authorization": "Bearer {}".format('AAAAAAAAAAAAAAAAAAAAAFfoZgEAAAAAR8cAl2V37CUrUQ5lDePVnjHNfAA%3DoRUnSWMlcIpWrm76oZToXJETBUrKlvmQccKFZoKniFOp8tRSjK')}
    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}".format(query, tweet_fields)
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

query = "siri die"
#twitter fields to be returned by api call
tweet_fields = "tweet.fields=text,author_id,created_at"
json_response = search_twitter(query=query, tweet_fields=tweet_fields, bearer_token='AAAAAAAAAAAAAAAAAAAAAFfoZgEAAAAAR8cAl2V37CUrUQ5lDePVnjHNfAA%3DoRUnSWMlcIpWrm76oZToXJETBUrKlvmQccKFZoKniFOp8tRSjK')
#pretty printing
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "1457831305",
#             "created_at": "2022-02-28T16:07:55.000Z",
#             "id": "1498329122539544579",
#             "text": "@die_nerd_siri Hoff du liest nicht alles korrektur bei mir \ud83e\udd23 sonst hast k1 Freizeit mehr \ud83d\ude48\ud83d\ude4a"
#         },
#         {
#             "author_id": "1457831305",
#             "created_at": "2022-02-28T16:03:01.000Z",
#             "id": "1498327889397309453",
#             "text": "@die_nerd_siri Hach, das mit dem Hochdeutsch werd ich wohl nicht mehr lernen \ud83d\ude2a"
#         },
#         {
#             "author_id": "1234497215944708097",
#             "created_at": "2022-02-28T16:00:07.000Z",
#             "id": "1498327161014525968",
#             "text": "Darunter Literaturnobelpreistr\u00e4ger  Swetlana Alexijewitsch,\u00a0Orhan Pamuk\u00a0und\u00a0Olga Tokarczuk.\u00a0Die  Erkl\u00e4rung wurde auch von z B von Margaret Atwood,\u00a0Paul Auster,\u00a0Can D\u00fcndar,\u00a0Jonathan Franzen,Siri Hustvedt,\u00a0Joyce Carol Oates,\u00a0Salman Rushdie, Elif Shafak\u00a0unterzeichnet\n#Schriftsteller https://t.co/Or6JemZhGt"
#         },
#         {
#             "author_id": "1468891684981420039",
#             "created_at": "2022-02-28T15:05:47.000Z",
#             "id": "1498313486509740039",
#             "text": "@siri_privat Und ich, wenn ich die ersten depperten Beitr\u00e4ge auf Twitter sehe \ud83d\ude39"
#         },
#         {
#             "author_id": "1396030038332612612",
#             "created_at": "2022-02-28T12:21:06.000Z",
#             "id": "1498272043741196297",
#             "text": "RT @RonenSteinke: Siri! Ich sage Waffenlieferungen an die Ukraine, du schreibst Waffenlieferungen an Christine"
#         },
#         {
#             "author_id": "1436929379016355841",
#             "created_at": "2022-02-28T10:50:53.000Z",
#             "id": "1498249339398987781",
#             "text": "@siri_privat Oh. Stimmt. Lese gerade, dass meine auch nur noch bis dieses Jahr gilt.\n\nich hatte mal eine bei der Advanzia Bank. Such mal nach geb\u00fchrenfrei Mastercard. Die hab ich aber nie benutzt."
#         },
#         {
#             "author_id": "1436929379016355841",
#             "created_at": "2022-02-28T10:34:07.000Z",
#             "id": "1498245120134635521",
#             "text": "@siri_privat Ich versteh das. Ich habe die Amazon Visa genommen. Die kostet 1 Jahr nichts, danach nur 19,99 \u20ac."
#         },
#         {
#             "author_id": "372780330",
#             "created_at": "2022-02-28T10:19:46.000Z",
#             "id": "1498241510403358723",
#             "text": "@siri_privat Gute Besserung und komm schnell wieder auf die Beine!"
#         },
#         {
#             "author_id": "464970303",
#             "created_at": "2022-02-28T10:16:10.000Z",
#             "id": "1498240604366839809",
#             "text": "Siri! Ich sage Waffenlieferungen an die Ukraine, du schreibst Waffenlieferungen an Christine"
#         },
#         {
#             "author_id": "1162730793472385026",
#             "created_at": "2022-02-28T09:51:37.000Z",
#             "id": "1498234424554815491",
#             "text": "@VitaminnT_ Hey Siri how to not die to omen a million times"
#         }
#     ],
#     "meta": {
#         "newest_id": "1498329122539544579",
#         "next_token": "b26v89c19zqg8o3fpe7897711mnvfz4o3ojr7z450p9q5",
#         "oldest_id": "1498234424554815491",
#         "result_count": 10
#     }
# }
