# %%
import stackapi
from stackapi import StackAPI
site = StackAPI('stackoverflow')
questions = site.fetch('questions', fromdate = 1643673600, todate = 1646043623)
questions
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2944/928701508.py in <module>
#       2 from stackapi import StackAPI
#       3 site = StackAPI('stackoverflow')
# ----> 4 questions = site.fetch('questions', fromdate = 1643673600, todate = 1646043623)
#       5 questions
#
# ~\anaconda3\lib\site-packages\stackapi\stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     210                 code = response["error_name"]
#     211                 message = response["error_message"]
# --> 212                 raise StackAPIError(self._previous_call, error, code, message)
#     213             except KeyError:
#     214                 pass  # This means there is no error
#
# ...

# %%
answers = site.fetch('answers', fromdate = 1643673600, todate = 1646043623)
answers
# Out:
# {'backoff': 10,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 22,
#  'total': 0,
#  'items': [{'owner': {'reputation': 1,
#     'user_id': 17863822,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f3289754ec7658bd1ff61933517746b0?s=256&d=identicon&r=PG',
#     'display_name': 'RuffG',
#     'link': 'https://stackoverflow.com/users/17863822/ruffg'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1646129924,
#    'last_edit_date': 1646129924,
#    'creation_date': 1646041013,
#    'answer_id': 71292978,
#    'question_id': 19399022,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 13,
#     'user_id': 11652205,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5070494c54e8150d5b23a49694b626d0?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'Ithrandil',
#     'link': 'https://stackoverflow.com/users/11652205/ithrandil'},
# ...

# %%
most_voted = site.fetch('questions', fromdate = 1646043623, todate = 1646130023, min = 5, tagged = 'python', sort = 'votes')
most_voted

# %%
answers2 = site.fetch('answers', ids=[6784, 6473])
answers
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2944/2455407938.py in <module>
# ----> 1 answers2 = site.fetch('answers', ids=[6784, 6473])
#       2 answers
#
# ~\anaconda3\lib\site-packages\stackapi\stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     210                 code = response["error_name"]
#     211                 message = response["error_message"]
# --> 212                 raise StackAPIError(self._previous_call, error, code, message)
#     213             except KeyError:
#     214                 pass  # This means there is no error
#
# StackAPIError: ('https://api.stackexchange.com/2.2/answers/6784;6473/?pagesize=100&page=1&filter=default&site=stackoverflow', 502, 'throttle_violation', 'too many requests from this IP, more requests available in 11083 seconds')
